# %%
import dspy

lm = dspy.LM('openai/gpt-4o-mini')
dspy.configure(lm=lm)

# %%
qa = dspy.Predict('question: str -> response: str')
response = qa(question="what are high memory and low memory on linux?")

print(response.response)
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniforge/base/envs/nunu24/lib/python3.12/site-packages/litellm/llms/OpenAI/openai.py:854, in OpenAIChatCompletion.completion(self, model_response, timeout, optional_params, logging_obj, model, messages, print_verbose, api_key, api_base, acompletion, litellm_params, logger_fn, headers, custom_prompt_dict, client, organization, custom_llm_provider, drop_params)
#     853             else:
# --> 854                 raise e
#     855 except OpenAIError as e:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/nunu24/lib/python3.12/site-packages/litellm/llms/OpenAI/openai.py:767, in OpenAIChatCompletion.completion(self, model_response, timeout, optional_params, logging_obj, model, messages, print_verbose, api_key, api_base, acompletion, litellm_params, logger_fn, headers, custom_prompt_dict, client, organization, custom_llm_provider, drop_params)
#     763     raise OpenAIError(
#     764         status_code=422, message="max retries must be an int"
#     765     )
# --> 767 openai_client: OpenAI = self._get_openai_client(  # type: ignore
#     768     is_async=False,
#     769     api_key=api_key,
#     770     api_base=api_base,
#     771     timeout=timeout,
#     772     max_retries=max_retries,
#     773     organization=organization,
#     774     client=client,
#     775 )
#     777 ## LOGGING
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/nunu24/lib/python3.12/site-packages/litellm/llms/OpenAI/openai.py:575, in OpenAIChatCompletion._get_openai_client(self, is_async, api_key, api_base, timeout, max_retries, organization, client)
#     574 else:
# --> 575     _new_client = OpenAI(
#     576         api_key=api_key,
#     577         base_url=api_base,
#     578         http_client=litellm.client_session,
#     579         timeout=timeout,
#     580         max_retries=max_retries,
#     581         organization=organization,
#     582     )
#     584 ## SAVE CACHE KEY
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/nunu24/lib/python3.12/site-packages/openai/_client.py:105, in OpenAI.__init__(self, api_key, organization, project, base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     104 if api_key is None:
# --> 105     raise OpenAIError(
#     106         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     107     )
#     108 self.api_key = api_key
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable
#
# During handling of the above exception, another exception occurred:
#
# OpenAIError                               Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniforge/base/envs/nunu24/lib/python3.12/site-packages/litellm/main.py:1597, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, audio, presence_penalty, frequency_penalty, logit_bias, user, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, **kwargs)
#    1591     logging.post_call(
#    1592         input=messages,
#    1593         api_key=api_key,
#    1594         original_response=str(e),
#    1595         additional_args={"headers": headers},
#    1596     )
# -> 1597     raise e
#    1599 if optional_params.get("stream", False):
#    1600     ## LOGGING
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/nunu24/lib/python3.12/site-packages/litellm/main.py:1570, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, audio, presence_penalty, frequency_penalty, logit_bias, user, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, **kwargs)
#    1569     else:
# -> 1570         response = openai_chat_completions.completion(
#    1571             model=model,
#    1572             messages=messages,
#    1573             headers=headers,
#    1574             model_response=model_response,
#    1575             print_verbose=print_verbose,
#    1576             api_key=api_key,
#    1577             api_base=api_base,
#    1578             acompletion=acompletion,
#    1579             logging_obj=logging,
#    1580             optional_params=optional_params,
#    1581             litellm_params=litellm_params,
#    1582             logger_fn=logger_fn,
#    1583             timeout=timeout,  # type: ignore
#    1584             custom_prompt_dict=custom_prompt_dict,
#    1585             client=client,  # pass AsyncOpenAI, OpenAI client
#    1586             organization=organization,
#    1587             custom_llm_provider=custom_llm_provider,
#    1588         )
#    1589 except Exception as e:
#    1590     ## LOGGING - log the original exception returned
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/nunu24/lib/python3.12/site-packages/litellm/llms/OpenAI/openai.py:864, in OpenAIChatCompletion.completion(self, model_response, timeout, optional_params, logging_obj, model, messages, print_verbose, api_key, api_base, acompletion, litellm_params, logger_fn, headers, custom_prompt_dict, client, organization, custom_llm_provider, drop_params)
#     863     error_headers = getattr(error_response, "headers", None)
# --> 864 raise OpenAIError(
#     865     status_code=status_code, message=error_text, headers=error_headers
#     866 )
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable
#
# During handling of the above exception, another exception occurred:
#
# AuthenticationError                       Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniforge/base/envs/nunu24/lib/python3.12/site-packages/litellm/utils.py:903, in client.<locals>.wrapper(*args, **kwargs)
#     902 # MODEL CALL
# --> 903 result = original_function(*args, **kwargs)
#     904 end_time = datetime.datetime.now()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/nunu24/lib/python3.12/site-packages/litellm/main.py:3009, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, audio, presence_penalty, frequency_penalty, logit_bias, user, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, **kwargs)
#    3007 except Exception as e:
#    3008     ## Map to OpenAI Exception
# -> 3009     raise exception_type(
#    3010         model=model,
#    3011         custom_llm_provider=custom_llm_provider,
#    3012         original_exception=e,
#    3013         completion_kwargs=args,
#    3014         extra_kwargs=kwargs,
#    3015     )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/nunu24/lib/python3.12/site-packages/litellm/litellm_core_utils/exception_mapping_utils.py:2116, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2115     setattr(e, "litellm_response_headers", litellm_response_headers)
# -> 2116     raise e
#    2117 else:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/nunu24/lib/python3.12/site-packages/litellm/litellm_core_utils/exception_mapping_utils.py:310, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#     309     exception_mapping_worked = True
# --> 310     raise AuthenticationError(
#     311         message=f"AuthenticationError: {exception_provider} - {message}",
#     312         llm_provider=custom_llm_provider,
#     313         model=model,
#     314         response=original_exception.response,
#     315         litellm_debug_info=extra_information,
#     316     )
#     317 elif "Mistral API raised a streaming error" in error_str:
#
# AuthenticationError: litellm.AuthenticationError: AuthenticationError: OpenAIException - The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable
#
# During handling of the above exception, another exception occurred:
#
# AuthenticationError                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 qa = dspy.Predict('question: str -> response: str')
# ----> 2 response = qa(question="what are high memory and low memory on linux?")
#       4 print(response.response)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/nunu24/lib/python3.12/site-packages/dspy/utils/callback.py:202, in with_callbacks.<locals>.wrapper(instance, *args, **kwargs)
#     200 # If no callbacks are provided, just call the function
#     201 if not callbacks:
# --> 202     return fn(instance, *args, **kwargs)
#     204 # Generate call ID as the unique identifier for the call, this is useful for instrumentation.
#     205 call_id = uuid.uuid4().hex
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/nunu24/lib/python3.12/site-packages/dspy/predict/predict.py:154, in Predict.__call__(self, **kwargs)
#     152 @with_callbacks
#     153 def __call__(self, **kwargs):
# --> 154     return self.forward(**kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/nunu24/lib/python3.12/site-packages/dspy/predict/predict.py:188, in Predict.forward(self, **kwargs)
#     185 import dspy
#     187 if isinstance(lm, dspy.LM):
# --> 188     completions = v2_5_generate(lm, config, signature, demos, kwargs, _parse_values=self._parse_values)
#     189 else:
#     190     warn_once(
#     191         "\t*** In DSPy 2.5, all LM clients except `dspy.LM` are deprecated, "
#     192         "underperform, and are about to be deleted. ***\n"
#    (...)
#     197         " \t\thttps://github.com/stanfordnlp/dspy/blob/main/examples/migration.ipynb"
#     198     )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/nunu24/lib/python3.12/site-packages/dspy/predict/predict.py:295, in v2_5_generate(lm, lm_kwargs, signature, demos, inputs, _parse_values)
#     291 import dspy
#     293 adapter = dspy.settings.adapter or dspy.ChatAdapter()
# --> 295 return adapter(
#     296     lm, lm_kwargs=lm_kwargs, signature=signature, demos=demos, inputs=inputs, _parse_values=_parse_values
#     297 )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/nunu24/lib/python3.12/site-packages/dspy/adapters/base.py:20, in Adapter.__call__(self, lm, lm_kwargs, signature, demos, inputs, _parse_values)
#      17 inputs_ = self.format(signature, demos, inputs)
#      18 inputs_ = dict(prompt=inputs_) if isinstance(inputs_, str) else dict(messages=inputs_)
# ---> 20 outputs = lm(**inputs_, **lm_kwargs)
#      21 values = []
#      23 try:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/nunu24/lib/python3.12/site-packages/dspy/utils/callback.py:202, in with_callbacks.<locals>.wrapper(instance, *args, **kwargs)
#     200 # If no callbacks are provided, just call the function
#     201 if not callbacks:
# --> 202     return fn(instance, *args, **kwargs)
#     204 # Generate call ID as the unique identifier for the call, this is useful for instrumentation.
#     205 call_id = uuid.uuid4().hex
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/nunu24/lib/python3.12/site-packages/dspy/clients/lm.py:94, in LM.__call__(self, prompt, messages, **kwargs)
#      91 else:
#      92     completion = cached_litellm_text_completion if cache else litellm_text_completion
# ---> 94 response = completion(
#      95     request=ujson.dumps(dict(model=self.model, messages=messages, **kwargs)),
#      96     num_retries=self.num_retries,
#      97 )
#      98 outputs = [c.message.content if hasattr(c, "message") else c["text"] for c in response["choices"]]
#     100 # Logging, with removed api key & where `cost` is None on cache hit.
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/nunu24/lib/python3.12/site-packages/dspy/clients/lm.py:217, in cached_litellm_completion(request, num_retries)
#     215 @functools.lru_cache(maxsize=None)
#     216 def cached_litellm_completion(request, num_retries: int):
# --> 217     return litellm_completion(
#     218         request,
#     219         cache={"no-cache": False, "no-store": False},
#     220         num_retries=num_retries,
#     221     )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/nunu24/lib/python3.12/site-packages/dspy/clients/lm.py:226, in litellm_completion(request, num_retries, cache)
#     224 def litellm_completion(request, num_retries: int, cache={"no-cache": True, "no-store": True}):
#     225     kwargs = ujson.loads(request)
# --> 226     return litellm.completion(
#     227         num_retries=num_retries,
#     228         cache=cache,
#     229         **kwargs,
#     230     )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/nunu24/lib/python3.12/site-packages/litellm/utils.py:993, in client.<locals>.wrapper(*args, **kwargs)
#     987     if (
#     988         isinstance(e, openai.APIError)
#     989         or isinstance(e, openai.Timeout)
#     990         or isinstance(e, openai.APIConnectionError)
#     991     ):
#     992         kwargs["num_retries"] = num_retries
# --> 993         return litellm.completion_with_retries(*args, **kwargs)
#     994 elif (
#     995     isinstance(e, litellm.exceptions.ContextWindowExceededError)
#     996     and context_window_fallback_dict
#     997     and model in context_window_fallback_dict
#     998     and not _is_litellm_router_call
#     999 ):
#    1000     if len(args) > 0:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/nunu24/lib/python3.12/site-packages/litellm/main.py:3042, in completion_with_retries(*args, **kwargs)
#    3038 else:
#    3039     retryer = tenacity.Retrying(
#    3040         stop=tenacity.stop_after_attempt(num_retries), reraise=True
#    3041     )
# -> 3042 return retryer(original_function, *args, **kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/nunu24/lib/python3.12/site-packages/tenacity/__init__.py:475, in Retrying.__call__(self, fn, *args, **kwargs)
#     473 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     474 while True:
# --> 475     do = self.iter(retry_state=retry_state)
#     476     if isinstance(do, DoAttempt):
#     477         try:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/nunu24/lib/python3.12/site-packages/tenacity/__init__.py:376, in BaseRetrying.iter(self, retry_state)
#     374 result = None
#     375 for action in self.iter_state.actions:
# --> 376     result = action(retry_state)
#     377 return result
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/nunu24/lib/python3.12/site-packages/tenacity/__init__.py:418, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     416 retry_exc = self.retry_error_cls(fut)
#     417 if self.reraise:
# --> 418     raise retry_exc.reraise()
#     419 raise retry_exc from fut.exception()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/nunu24/lib/python3.12/site-packages/tenacity/__init__.py:185, in RetryError.reraise(self)
#     183 def reraise(self) -> t.NoReturn:
#     184     if self.last_attempt.failed:
# --> 185         raise self.last_attempt.result()
#     186     raise self
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/nunu24/lib/python3.12/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/nunu24/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/nunu24/lib/python3.12/site-packages/tenacity/__init__.py:478, in Retrying.__call__(self, fn, *args, **kwargs)
#     476 if isinstance(do, DoAttempt):
#     477     try:
# --> 478         result = fn(*args, **kwargs)
#     479     except BaseException:  # noqa: B902
#     480         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/nunu24/lib/python3.12/site-packages/litellm/utils.py:1013, in client.<locals>.wrapper(*args, **kwargs)
#    1009 if logging_obj:
#    1010     logging_obj.failure_handler(
#    1011         e, traceback_exception, start_time, end_time
#    1012     )  # DO NOT MAKE THREADED - router retry fallback relies on this!
# -> 1013 raise e
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/nunu24/lib/python3.12/site-packages/litellm/utils.py:903, in client.<locals>.wrapper(*args, **kwargs)
#     901         print_verbose(f"Error while checking max token limit: {str(e)}")
#     902 # MODEL CALL
# --> 903 result = original_function(*args, **kwargs)
#     904 end_time = datetime.datetime.now()
#     905 if "stream" in kwargs and kwargs["stream"] is True:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/nunu24/lib/python3.12/site-packages/litellm/main.py:3009, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, audio, presence_penalty, frequency_penalty, logit_bias, user, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, **kwargs)
#    3006     return response
#    3007 except Exception as e:
#    3008     ## Map to OpenAI Exception
# -> 3009     raise exception_type(
#    3010         model=model,
#    3011         custom_llm_provider=custom_llm_provider,
#    3012         original_exception=e,
#    3013         completion_kwargs=args,
#    3014         extra_kwargs=kwargs,
#    3015     )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/nunu24/lib/python3.12/site-packages/litellm/litellm_core_utils/exception_mapping_utils.py:2116, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2114 if exception_mapping_worked:
#    2115     setattr(e, "litellm_response_headers", litellm_response_headers)
# -> 2116     raise e
#    2117 else:
#    2118     for error_type in litellm.LITELLM_EXCEPTION_TYPES:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/nunu24/lib/python3.12/site-packages/litellm/litellm_core_utils/exception_mapping_utils.py:310, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#     305 elif (
#     306     "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     307     in error_str
#     308 ):
#     309     exception_mapping_worked = True
# --> 310     raise AuthenticationError(
#     311         message=f"AuthenticationError: {exception_provider} - {message}",
#     312         llm_provider=custom_llm_provider,
#     313         model=model,
#     314         response=original_exception.response,
#     315         litellm_debug_info=extra_information,
#     316     )
#     317 elif "Mistral API raised a streaming error" in error_str:
#     318     exception_mapping_worked = True
#
# AuthenticationError: litellm.AuthenticationError: AuthenticationError: OpenAIException - The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable

# %%
dspy.inspect_history(n=1)

# %%
cot = dspy.ChainOfThought('question -> response')
cot(question="should curly braces appear on their own line?")

# %%
# So far, we built a very simple chain-of-thought module for question answering and evaluated it on a small dataset.
# now we do thee RAG!!!

# %%
# full code block 
download("https://huggingface.co/dspy/cache/resolve/main/ragqa_arena_tech_corpus.jsonl")

# as far as DSPy is concerned, you can plug in any Python code for calling tools or retrievers.

# %pip install -U faiss-cpu  # or faiss-gpu if you have a GPU

max_characters = 6000  # for truncating >99th percentile of documents
topk_docs_to_retrieve = 5  # number of documents to retrieve per search query

with open("ragqa_arena_tech_corpus.jsonl") as f:
    corpus = [ujson.loads(line)['text'][:max_characters] for line in f]
    print(f"Loaded {len(corpus)} documents. Will encode them below.")

embedder = dspy.Embedder('openai/text-embedding-3-small', dimensions=512)
search = dspy.retrievers.Embeddings(embedder=embedder, corpus=corpus, k=topk_docs_to_retrieve)

class RAG(dspy.Module):
    def __init__(self):
        self.respond = dspy.ChainOfThought('context, question -> response')

    def forward(self, question):
        context = search(question).passages
        return self.respond(context=context, question=question)
    
rag = RAG()
rag(question="what are high memory and low memory on linux?")

dspy.inspect_history()

evaluate(RAG())

tp = dspy.MIPROv2(metric=metric, auto="medium", num_threads=24)  # use fewer threads if your rate limit is small

optimized_rag = tp.compile(RAG(), trainset=trainset,
                           max_bootstrapped_demos=2, max_labeled_demos=2,
                           requires_permission_to_run=False)

baseline = rag(question="cmd+tab does not work on hidden or minimized windows")
print(baseline.response)

pred = optimized_rag(question="cmd+tab does not work on hidden or minimized windows")
print(pred.response)

# You can use dspy.inspect_history(n=2) to view the RAG prompt before optimization and after optimization.

cost = sum([x['cost'] for x in lm.history if x['cost'] is not None])  # in USD, as calculated by LiteLLM for certain providers

optimized_rag.save("optimized_rag.json")

loaded_rag = RAG()
loaded_rag.load("optimized_rag.json")

loaded_rag(question="cmd+tab does not work on hidden or minimized windows")
